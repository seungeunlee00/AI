# %% [markdown]
# <a href="https://colab.research.google.com/github/seungeunlee00/JUNIA/blob/main/AI/3-ML2/Mean_Shift_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # 드라이브 마운트 필수
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.cluster import MeanShift
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Simulate input data

# %%
np.random.seed(1)
x, _ = make_blobs(n_samples=300, centers=5, cluster_std=.8)
plt.scatter(x[:,0], x[:,1])
plt.show()

# %% [markdown]
# # Create and fit a Mean Shift Clustering

# %%
mshclust=MeanShift(bandwidth=2)
mshclust.fit(x)
# Out:
# MeanShift(bandwidth=2)

# %% [markdown]
# # Display output

# %%
labels = mshclust.labels_
centers = mshclust.cluster_centers_

plt.scatter(x[:,0], x[:,1], c=labels)
plt.scatter(centers[:,0],centers[:,1], marker='*', color="r",s=80 )
plt.show()
