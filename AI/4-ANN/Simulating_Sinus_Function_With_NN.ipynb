# %% [markdown]
# <a href="https://colab.research.google.com/github/seungeunlee00/JUNIA/blob/main/AI/4-ANN/Simulating_Sinus_Function_With_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simulating Sinus Function with a neural network

# %%
from math import sin
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Generating input data

# %%
data_list=[]
for i in range (1000):
	x = i*3.1415*2/1000
	y = 10 * sin(x)
	data_list.append([x,y])
data = np.array(data_list)
X = data[:,0]
print(X)
Y = data[:,1]
print(Y)
# Out:
# [0.       0.006283 0.012566 0.018849 0.025132 0.031415 0.037698 0.043981
#  0.050264 0.056547 0.06283  0.069113 0.075396 0.081679 0.087962 0.094245
#  0.100528 0.106811 0.113094 0.119377 0.12566  0.131943 0.138226 0.144509
#  0.150792 0.157075 0.163358 0.169641 0.175924 0.182207 0.18849  0.194773
#  0.201056 0.207339 0.213622 0.219905 0.226188 0.232471 0.238754 0.245037
#  0.25132  0.257603 0.263886 0.270169 0.276452 0.282735 0.289018 0.295301
#  0.301584 0.307867 0.31415  0.320433 0.326716 0.332999 0.339282 0.345565
#  0.351848 0.358131 0.364414 0.370697 0.37698  0.383263 0.389546 0.395829
#  0.402112 0.408395 0.414678 0.420961 0.427244 0.433527 0.43981  0.446093
#  0.452376 0.458659 0.464942 0.471225 0.477508 0.483791 0.490074 0.496357
#  0.50264  0.508923 0.515206 0.521489 0.527772 0.534055 0.540338 0.546621
#  0.552904 0.559187 0.56547  0.571753 0.578036 0.584319 0.590602 0.596885
#  0.603168 0.609451 0.615734 0.622017 0.6283   0.634583 0.640866 0.647149
# ...

# %%
plt.scatter(X, Y)
plt.show()

# %%
model = Sequential()

model.add(Dense(32, input_dim=1, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                64
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# ...
# Total params: 1,153
# Trainable params: 1,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, Y, epochs = 100, verbose=1)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 3ms/step - loss: 39.8442
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 25.1753
# Epoch 3/100
# 32/32 [==============================] - 0s 4ms/step - loss: 13.8081
# Epoch 4/100
# 32/32 [==============================] - 0s 3ms/step - loss: 11.8236
# Epoch 5/100
# 32/32 [==============================] - 0s 4ms/step - loss: 10.3799
# Epoch 6/100
# 32/32 [==============================] - 0s 4ms/step - loss: 9.1800
# Epoch 7/100
# 32/32 [==============================] - 0s 4ms/step - loss: 8.6368
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.4604
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 6.5418
# Epoch 10/100
# 32/32 [==============================] - 0s 2ms/step - loss: 5.9108
# Epoch 11/100
# 32/32 [==============================] - 0s 2ms/step - loss: 5.3130
# Epoch 12/100
# ...

# %%
Y_predict = model.predict(X)
#print(Y_predict)

plt.scatter(X, Y)
plt.scatter(X, Y_predict)
plt.show()
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
model.predict([0, 3.1415/2])
# Out:
# 1/1 [==============================] - 0s 33ms/step
# array([[ 0.16328472],
#        [10.146222  ]], dtype=float32)
