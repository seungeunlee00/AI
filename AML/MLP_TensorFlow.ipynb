# %% [markdown]
# <a href="https://colab.research.google.com/github/seungeunlee00/JUNIA/blob/main/AML/MLP_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting started with Keras - TensorFlow core

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1. Import necessary packages and load your dataset
import tensorflow as tf
import numpy as np

# specify Training base S: (X:x_train, Y:y_train)
x_train = np.array([[0, 0],
                    [0, 1],
                    [1, 0],
                    [1, 1]])
y_train = np.array([[0], [1], [1], [0]]) # XOR

# 2. Create a sequential model (neural network architexture)
model = tf.keras.Sequential() # at this stage of code, the model is empty

# 3. Building the architecture of our model by adding layers
# Dense(5) is a fully-connected layer with 5 hidden units.
# in the first layer, you must specify the expected input data shape:
# here, vector of 2 inputs.
model.add(tf.keras.layers.Dense(5, activation='relu', input_dim=2))
model.add(tf.keras.layers.Dense(3, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# 4. Specifying how to update the weights -> optimizers
# we want to use stochastic gradient descent with learning rate=0.02
sgd = tf.keras.optimizers.SGD(lr=0.02)

# 5. Compile the model: Set loss function, optimizer and evaluation metrics
model.compile(loss='mean_squared_error',
              optimizer='sgd',
              metrics=['mean_squared_error'])

# 6. Train the model on data: training base S
model.fit(x_train, y_train, batch_size=1, epochs=20)
# Out:
# Epoch 1/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 2/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 3/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 4/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 5/20
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 6/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 7/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 8/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 9/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 10/20
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 11/20
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 12/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 13/20
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 14/20
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 15/20
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 16/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 17/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 18/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 19/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503
# Epoch 20/20
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - mean_squared_error: 0.2503

# %%
# 7. Use predict and round functions of your model
print(model.predict(x_train))
print(model.predict(x_train).round())
# Out:
# 1/1 [==============================] - 0s 56ms/step
# [[0.4999968 ]
#  [0.4999968 ]
#  [0.50001764]
#  [0.4999968 ]]
# 1/1 [==============================] - 0s 22ms/step
# [[0.]
#  [0.]
#  [1.]
#  [0.]]

# %%
print(model.layers[0].get_weights())
print(model.layers[1].get_weights())
print(model.layers[2].get_weights())
# Out:
# [array([[-0.29613966, -0.18352646,  0.20952892, -0.10956931, -0.43330076],
#        [ 0.6277616 ,  0.41281235,  0.87639916,  0.4789002 ,  0.73735416]],
#       dtype=float32), array([0.000000e+00, 0.000000e+00, 5.665066e-07, 0.000000e+00,
#        0.000000e+00], dtype=float32)]
# [array([[ 0.0473814 , -0.8410339 ,  0.04697198],
#        [ 0.6642683 ,  0.24448067,  0.39491552],
#        [-0.71406794, -0.4879078 ,  0.11123971],
#        [ 0.6524382 ,  0.04293638, -0.73245037],
#        [-0.3995515 , -0.52564365, -0.6946375 ]], dtype=float32), array([0.0000000e+00, 0.0000000e+00, 5.0947647e-06], dtype=float32)]
# [array([[1.0504054 ],
#        [0.06573689],
#        [0.00357252]], dtype=float32), array([-1.2751669e-05], dtype=float32)]
